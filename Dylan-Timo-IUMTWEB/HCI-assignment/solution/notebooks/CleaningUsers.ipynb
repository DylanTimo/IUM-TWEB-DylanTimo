# %%
import pandas as pd
import sys
sys.path.append("./modules")
from modules.Cleaning import *
from modules.Functions import *

# %% [markdown]
# ### Profiles df
# - dropping duplicates
# - filling na values
# - normalizing nation names
# - normalizing types

# %%
dfProfiles = pd.read_csv("../data/raw/profiles.csv")
dfProfiles = clean_user_profiles(dfProfiles)
dfProfiles
# Out:
#            username   gender   birthday                  location     joined  \
# 0         ishikawas  Unknown        NaT               South Korea        NaT
# 1              CKK2  Unknown        NaT  United States of America 2018-12-01
# 2       --------788   Female        NaT                    Mexico 2022-10-04
# 3        potatoaris  Unknown        NaT                     Spain 2018-10-02
# 4         Rinrintan  Unknown        NaT                     Japan 2019-05-12
# ...             ...      ...        ...                       ...        ...
# 337150  ariyanroy04  Unknown        NaT  United States of America 2021-03-30
# 337151   ariyanvk18     Male        NaT                    Turkey 2022-01-24
# 337152     ariyoskz  Unknown        NaT                   Germany 2022-07-07
# 337153    arizima23   Female 1998-06-23                     Spain 2019-03-15
# 337154      arizkim  Unknown        NaT              South Africa 2020-12-07
#
#         watching  completed  on_hold  dropped  plan_to_watch
# 0              0          0        0        0              0
# 1              3        182       15        0            405
# 2              1         64        0        0              1
# 3              5          1        0        0              4
# 4             20        311       40       16             34
# ...          ...        ...      ...      ...            ...
# 337150        35        130        0        0            489
# 337151         7        101        1       12             21
# 337152         1        155        2       11             15
# 337153        15         64        0        4              4
# 337154         7         38        1        0             33
#
# [337154 rows x 10 columns]

# %% [markdown]
# Unluckily there is only 22 locations

# %%
dfProfiles["location"].unique()
# Out:
# <StringArray>
# [             'South Korea', 'United States of America',
#                    'Mexico',                    'Spain',
#                     'Japan',                   'Turkey',
#                 'Indonesia',                'Argentina',
#                    'France',                 'Thailand',
#                   'Germany',                'Australia',
#                     'China',                    'Italy',
#            'United Kingdom',             'South Africa',
#                     'Egypt',              'Philippines',
#                     'India',                   'Canada',
#                    'Brazil',                  'Vietnam']
# Length: 22, dtype: str

# %%
save_csv(dfProfiles, "../data/cleaned/users_profiles.csv")
dfProfiles = None

# %% [markdown]
# ### Ratings df
# ##### Note: heavy file, use nrows to reduce load
# - filling na values
# - removing outliers

# %%
dfRatings = pd.read_csv("../data/raw/ratings.csv")
dfRatings = clean_favorites(dfRatings)
dfRatings
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 dfRatings = pd.read_csv("../data/raw/ratings.csv")
#       2 dfRatings = clean_favorites(dfRatings)
#       3 dfRatings
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:306, in _read(filepath_or_buffer, kwds)
#     303     return parser
#     305 with parser:
# --> 306     return parser.read(nrows)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:1992, in TextFileReader.read(self, nrows)
#    1989     else:
#    1990         new_col_dict = col_dict
# -> 1992     df = DataFrame(
#    1993         new_col_dict,
#    1994         columns=columns,
#    1995         index=index,
#    1996         copy=False,
#    1997     )
#    1999     self._currow += new_rows
#    2000 return df
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     763     mgr = self._init_mgr(
#     764         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     765     )
#     767 elif isinstance(data, dict):
#     768     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770 elif isinstance(data, ma.MaskedArray):
#     771     from numpy.ma import mrecords
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\construction.py:460, in dict_to_mgr(data, index, columns, dtype, copy)
#     441 if copy:
#     442     # We only need to copy arrays that will not get consolidated, i.e.
#     443     #  only EA arrays
#     444     arrays = [
#     445         (
#     446             x.copy()
#    (...)    457         for x in arrays
#     458     ]
# --> 460 return arrays_to_mgr(arrays, columns, index, dtype=dtype, consolidate=copy)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\construction.py:118, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, consolidate)
#     115         index = ensure_index(index)
#     117     # don't force copy because getting jammed in an ndarray anyway
# --> 118     arrays, refs = _homogenize(arrays, index, dtype)
#     119     # _homogenize ensures
#     120     #  - all(len(x) == len(index) for x in arrays)
#     121     #  - all(x.ndim == 1 for x in arrays)
#    (...)    124
#     125 else:
#     126     index = ensure_index(index)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\construction.py:596, in _homogenize(data, index, dtype)
#     592     else:
#     593         # Fast path: use lib.fast_multiget for dicts without missing keys
#     594         val = lib.fast_multiget(val, oindex._values, default=np.nan)
# --> 596 val = sanitize_array(val, index, dtype=dtype, copy=False)
#     597 com.require_length_match(val, index)
#     598 refs.append(None)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\construction.py:616, in sanitize_array(data, index, dtype, copy, allow_2d)
#     614 subarr = data
#     615 if data.dtype == object and infer_object:
# --> 616     subarr = lib.maybe_convert_objects(
#     617         data,
#     618         # Here we do not convert numeric dtypes, as if we wanted that,
#     619         #  numpy would have done it for us.
#     620         convert_numeric=False,
#     621         convert_non_numeric=True,
#     622         convert_to_nullable_dtype=False,
#     623         dtype_if_all_nat=np.dtype("M8[s]"),
#     624     )
#     625 elif data.dtype.kind == "U" and using_string_dtype():
#     626     from pandas.core.arrays.string_ import StringDtype
#
# File pandas/_libs/lib.pyx:2632, in pandas._libs.lib.maybe_convert_objects()
#
# MemoryError: Unable to allocate 948. MiB for an array with shape (124298357,) and data type uint64

# %%
save_csv(dfRatings, "../data/cleaned/users_ratings.csv")
dfRatings = None

# %% [markdown]
# ### Favs df
# - dropping duplicates
# - dropping rows where username na

# %%
dfFavs = pd.read_csv("../data/raw/favs.csv")
dfFavs = clean_favorites(dfFavs)
dfFavs

# %%
save_csv(dfFavs, "../data/cleaned/users_favs.csv")
dfFavs = None
